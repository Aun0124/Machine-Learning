# %% [markdown]
# <a href="https://colab.research.google.com/github/TANKIANAUN/Machine-Learning/blob/master/Read_image.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from skimage import io
import matplotlib.pyplot as plt

# %%
image=io.imread('ai.jpg')

# %%
plt.imshow(image)

# %%
image.shape
# Out:
# (177, 284, 3)

# %%
plt.imshow(image[:80,:150])
